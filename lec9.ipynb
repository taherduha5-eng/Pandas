# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
s = pd.Series([1,2,3,4])

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
# access

# %%
s[0]
# Out:
# np.int64(1)

# %%
# dataframe

# %%
x = {
    "name" : ["duha","tahr","muhamed"],
    "age" : [20,50,16],
    "score" : [90.0,77.0,66.7]
}

# %%
type(x)
# Out:
# dict

# %%
df = pd.DataFrame(x)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# index

# %%
df = pd.DataFrame(x , index=["a","b","c"])

# %%
df
# Out:
#       name  age  score
# a     duha   20   90.0
# b     tahr   50   77.0
# c  muhamed   16   66.7

# %%
x
# Out:
# {'name': ['duha', 'tahr', 'muhamed'],
#  'age': [20, 50, 16],
#  'score': [90.0, 77.0, 66.7]}

# %%
# columns
df = pd.DataFrame(x , columns=["name","age"])

# %%
df
# Out:
#       name  age
# 0     duha   20
# 1     tahr   50
# 2  muhamed   16

# %%
# arr > df

# %%
arr = np.random.randint(1,10,(3,3))

# %%
arr
# Out:
# array([[2, 1, 3],
#        [1, 6, 6],
#        [8, 1, 4]], dtype=int32)

# %%
df = pd.DataFrame(arr)

# %%
df
# Out:
#    0  1  2
# 0  2  1  3
# 1  1  6  6
# 2  8  1  4

# %%
# access columns feature

# %%
df = pd.DataFrame(x)

# %%
df
# Out:
#       name  age  score
# 0     duha   20   90.0
# 1     tahr   50   77.0
# 2  muhamed   16   66.7

# %%
# one column

# %%
df.name
# Out:
# 0       duha
# 1       tahr
# 2    muhamed
# Name: name, dtype: object

# %%
# access row

# %%
# loc, iloc

# %%
df.loc[0]
# Out:
# name     duha
# age        20
# score    90.0
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# name     duha
# age        20
# score    90.0
# Name: 0, dtype: object

# %%
df.loc[0:2]
# Out:
#       name  age  score
# 0     duha   20   90.0
# 1     tahr   50   77.0
# 2  muhamed   16   66.7

# %%
df.iloc[0:2]
# Out:
#    name  age  score
# 0  duha   20   90.0
# 1  tahr   50   77.0

# %%
# set condition

# %%
df
# Out:
#       name  age  score
# 0     duha   20   90.0
# 1     tahr   50   77.0
# 2  muhamed   16   66.7

# %%
df["age"]>20
# Out:
# 0    False
# 1     True
# 2    False
# Name: age, dtype: bool

# %%
df[df["age"]>20]
# Out:
#    name  age  score
# 1  tahr   50   77.0

# %%
(df["age"]> 20 )& (df["score"]>50)
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
# rename col

# %%
df
# Out:
#       name  age  score
# 0     duha   20   90.0
# 1     tahr   50   77.0
# 2  muhamed   16   66.7

# %%
df.rename({"name":"Name"}, axis = 1, inplace=True)

# %%
df
# Out:
#       Name  age  score
# 0     duha   20   90.0
# 1     tahr   50   77.0
# 2  muhamed   16   66.7

# %%
# add col

# %%
df["gender"] = ["F","M","F"]

# %%
df
# Out:
#       Name  age  score gender
# 0     duha   20   90.0      F
# 1     tahr   50   77.0      M
# 2  muhamed   16   66.7      F

# %%
# drop col

# %%
df.drop([0])
# Out:
#       Name  age  score gender
# 1     tahr   50   77.0      M
# 2  muhamed   16   66.7      F

# %%
#concate

# %%
x
# Out:
# {'name': ['duha', 'tahr', 'muhamed'],
#  'age': [20, 50, 16],
#  'score': [90.0, 77.0, 66.7]}

# %%
df1 = pd.DataFrame({
    "name" : ["duha","tahr","muhamed"],
    "age" : [20,50,16],
    "score" : [90.0,77.0,66.7]
})
df2 = pd.DataFrame({
    "name" : ["adam","tahr","muhamed"],
    "A_ge" : [7,50,16],
    "S_core" : [70.0,75.0,63.7]    
})

# %%
df1
# Out:
#       name  age  score
# 0     duha   20   90.0
# 1     tahr   50   77.0
# 2  muhamed   16   66.7

# %%
df2
# Out:
#       name  A_ge  S_core
# 0     adam     7    70.0
# 1     tahr    50    75.0
# 2  muhamed    16    63.7

# %%
pd.concat([df1,df2])
# Out:
#       name   age  score  A_ge  S_core
# 0     duha  20.0   90.0   NaN     NaN
# 1     tahr  50.0   77.0   NaN     NaN
# 2  muhamed  16.0   66.7   NaN     NaN
# 0     adam   NaN    NaN   7.0    70.0
# 1     tahr   NaN    NaN  50.0    75.0
# 2  muhamed   NaN    NaN  16.0    63.7

# %%
pd.concat([df1,df2], ignore_index=True)
# Out:
#       name   age  score  A_ge  S_core
# 0     duha  20.0   90.0   NaN     NaN
# 1     tahr  50.0   77.0   NaN     NaN
# 2  muhamed  16.0   66.7   NaN     NaN
# 3     adam   NaN    NaN   7.0    70.0
# 4     tahr   NaN    NaN  50.0    75.0
# 5  muhamed   NaN    NaN  16.0    63.7

# %%
# join

# %%
inner_df = pd.merge(df1,df2, on="name")

# %%
inner_df
# Out:
#       name  age  score  A_ge  S_core
# 0     tahr   50   77.0    50    75.0
# 1  muhamed   16   66.7    16    63.7

# %%
# sort by value

# %%
df1 = pd.DataFrame({
    "name" : ["duha","tahr","muhamed"],
    "age" : [20,50,16],
    "score" : [90.0,77.0,66.7]
})

# %%
df
# Out:
#       Name  age  score gender
# 0     duha   20   90.0      F
# 1     tahr   50   77.0      M
# 2  muhamed   16   66.7      F

# %%
df.sort_values(by= "age")
# Out:
#       Name  age  score gender
# 2  muhamed   16   66.7      F
# 0     duha   20   90.0      F
# 1     tahr   50   77.0      M

# %%
df.sort_values(by= "age", ascending=False)
# Out:
#       Name  age  score gender
# 1     tahr   50   77.0      M
# 0     duha   20   90.0      F
# 2  muhamed   16   66.7      F

# %%
# sample random

# %%
df
# Out:
#       Name  age  score gender
# 0     duha   20   90.0      F
# 1     tahr   50   77.0      M
# 2  muhamed   16   66.7      F

# %%
df.sample(n=2)
# Out:
#       Name  age  score gender
# 1     tahr   50   77.0      M
# 2  muhamed   16   66.7      F

# %%
df.sample(frac=0.5)
# Out:
#       Name  age  score gender
# 0     duha   20   90.0      F
# 2  muhamed   16   66.7      F

# %%
# sort by index

# %%
df1.sort_index()
# Out:
#       name  age  score
# 0     duha   20   90.0
# 1     tahr   50   77.0
# 2  muhamed   16   66.7

# %%
df1
# Out:
#       name  age  score
# 0     duha   20   90.0
# 1     tahr   50   77.0
# 2  muhamed   16   66.7

# %%
# replace

# %%
df = pd.DataFrame({
    "name" : ["duha","tahr","muhamed"],
    "age" : [20,50,16],
    "score" : [90.0,77.0,66.7],
    "gender": ['F','M','M']
})

# %%
df
# Out:
#       name  age  score gender
# 0     duha   20   90.0      F
# 1     tahr   50   77.0      M
# 2  muhamed   16   66.7      M

# %%
df["gender"]=df["gender"].replace({"M":"male"})

# %%
df
# Out:
#       name  age  score gender
# 0     duha   20   90.0      F
# 1     tahr   50   77.0   male
# 2  muhamed   16   66.7   male

# %%
# groupby , aggregation

# %%
df.groupby("gender")["score"].mean()
# Out:
# gender
# F       90.00
# male    71.85
# Name: score, dtype: float64

# %%
df.groupby("gender").agg({"score":"mean", "age":"max"})
# Out:
#         score  age
# gender
# F       90.00   20
# male    71.85   50

# %%
# apply > text

# %%
df = pd.DataFrame({
    "Name": ["aya","ahmed","omer","alic","bob"],
    "Age" : [25,24,22,26,20],
    "Salary" : [10000,20000,34000,50000,45000],
    "Gender" : ["F","M","M","F","M"],
    "Annul_Income" : [120000,300000,100000,450000,700000],
    
})

# %%
len(df)
# Out:
# 5

# %%
# ADD Col

# %%
import numpy as np

# %%
df["bouns"]=np.random.randint(1,1000, len(df))

# %%
df
# Out:
#     Name  Age  Income  Gender  Annul_Income  bouns
# 0    aya   25   10000  female        120000    487
# 1  ahmed   24   20000    male        300000    819
# 2   omer   22   34000    male        100000    123
# 3   alic   26   50000  female        450000    358
# 4    bob   20   45000    male        700000    201

# %%
df
# Out:
#     Name  Age  Income  Gender  Annul_Income  bouns
# 0    aya   25   10000  female        120000    487
# 1  ahmed   24   20000    male        300000    819
# 2   omer   22   34000    male        100000    123
# 3   alic   26   50000  female        450000    358
# 4    bob   20   45000    male        700000    201

# %%
df.rename({"Salary":"Income"}, axis = 1, inplace=True)

# %%
df
# Out:
#     Name  Age  Income Gender  Annul_Income  bouns
# 0    aya   25   10000      F        120000     30
# 1  ahmed   24   20000      M        300000     40
# 2   omer   22   34000      M        100000     44
# 3   alic   26   50000      F        450000    100
# 4    bob   20   45000      M        700000    333

# %%
df["Gender"]=df["Gender"].replace({"M":"male","F":"female"})

# %%
df["Gender"]
# Out:
# 0    female
# 1      male
# 2      male
# 3    female
# 4      male
# Name: Gender, dtype: object

# %%
# sort by value

# %%
df.sort_values(by= "Income")
# Out:
#     Name  Age  Income  Gender  Annul_Income  bouns
# 0    aya   25   10000  female        120000     30
# 1  ahmed   24   20000    male        300000     40
# 2   omer   22   34000    male        100000     44
# 4    bob   20   45000    male        700000    333
# 3   alic   26   50000  female        450000    100

# %%
# read data

# %%
df =pd.read_csv(r"C:\Users\DELL\Downloads\Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           NaN            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  147 non-null    float64
#  2   SepalWidthCm   146 non-null    float64
#  3   PetalLengthCm  148 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           NaN            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     147.000000    146.000000     148.000000    150.000000
# mean    75.500000       5.861224      3.047945       3.787838      1.198667
# std     43.445368       0.821996      0.435212       1.758165      0.763161
# min      1.000000       4.400000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.400000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df["Species"].nunique()
# Out:
# 3

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    3
# SepalWidthCm     4
# PetalLengthCm    2
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# duplication

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
# save
